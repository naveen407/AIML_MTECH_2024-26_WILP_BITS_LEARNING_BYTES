# %%
#Import necessary libraries 
# !pip install spacy
#!pip install -spacy download en_core_web_sm
# !pip install pytextrank
# Out:
# Requirement already satisfied: spacy in c:\users\asha m v\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy) (2.28.1)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy) (0.7.0)
# Requirement already satisfied: setuptools in c:\users\asha m v\anaconda3\lib\site-packages (from spacy) (63.4.1)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy) (1.10.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy) (1.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy) (8.1.9)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy) (2.4.6)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy) (4.64.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy) (21.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy) (1.24.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy) (0.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy) (1.0.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: jinja2 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\asha m v\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\asha m v\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asha m v\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\asha m v\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asha m v\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asha m v\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.14)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\asha m v\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\asha m v\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: colorama in c:\users\asha m v\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\asha m v\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\asha m v\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\asha m v\anaconda3\lib\site-packages (from jinja2->spacy) (2.0.1)
# Requirement already satisfied: pytextrank in c:\users\asha m v\anaconda3\lib\site-packages (3.2.5)
# Requirement already satisfied: graphviz>=0.13 in c:\users\asha m v\anaconda3\lib\site-packages (from pytextrank) (0.20.1)
# Requirement already satisfied: pygments>=2.7.4 in c:\users\asha m v\anaconda3\lib\site-packages (from pytextrank) (2.11.2)
# Requirement already satisfied: icecream>=2.1 in c:\users\asha m v\anaconda3\lib\site-packages (from pytextrank) (2.1.3)
# Requirement already satisfied: spacy>=3.0 in c:\users\asha m v\anaconda3\lib\site-packages (from pytextrank) (3.7.2)
# Requirement already satisfied: networkx[default]>=2.6 in c:\users\asha m v\anaconda3\lib\site-packages (from pytextrank) (2.8.4)
# Requirement already satisfied: scipy>=1.7 in c:\users\asha m v\anaconda3\lib\site-packages (from pytextrank) (1.9.1)
# Requirement already satisfied: colorama>=0.3.9 in c:\users\asha m v\anaconda3\lib\site-packages (from icecream>=2.1->pytextrank) (0.4.5)
# Requirement already satisfied: executing>=0.3.1 in c:\users\asha m v\anaconda3\lib\site-packages (from icecream>=2.1->pytextrank) (2.0.1)
# Requirement already satisfied: asttokens>=2.0.1 in c:\users\asha m v\anaconda3\lib\site-packages (from icecream>=2.1->pytextrank) (2.4.1)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\asha m v\anaconda3\lib\site-packages (from networkx[default]>=2.6->pytextrank) (3.5.2)
# Requirement already satisfied: numpy>=1.19 in c:\users\asha m v\anaconda3\lib\site-packages (from networkx[default]>=2.6->pytextrank) (1.24.3)
# Requirement already satisfied: pandas>=1.3 in c:\users\asha m v\anaconda3\lib\site-packages (from networkx[default]>=2.6->pytextrank) (1.4.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (2.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (2.28.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (3.0.12)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (1.10.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (0.10.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (1.0.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (21.3)
# Requirement already satisfied: jinja2 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (2.11.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (3.0.8)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (0.3.4)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (8.1.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (4.64.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (2.4.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (3.3.0)
# Requirement already satisfied: setuptools in c:\users\asha m v\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (63.4.1)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (0.7.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (5.2.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\asha m v\anaconda3\lib\site-packages (from spacy>=3.0->pytextrank) (2.0.8)
# Requirement already satisfied: six>=1.12.0 in c:\users\asha m v\anaconda3\lib\site-packages (from asttokens>=2.0.1->icecream>=2.1->pytextrank) (1.16.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\asha m v\anaconda3\lib\site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\asha m v\anaconda3\lib\site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\asha m v\anaconda3\lib\site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asha m v\anaconda3\lib\site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asha m v\anaconda3\lib\site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\asha m v\anaconda3\lib\site-packages (from matplotlib>=3.4->networkx[default]>=2.6->pytextrank) (9.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asha m v\anaconda3\lib\site-packages (from pandas>=1.3->networkx[default]>=2.6->pytextrank) (2022.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\asha m v\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0->pytextrank) (4.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\asha m v\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asha m v\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\asha m v\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asha m v\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (2022.9.14)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\asha m v\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy>=3.0->pytextrank) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\asha m v\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy>=3.0->pytextrank) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\asha m v\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy>=3.0->pytextrank) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\asha m v\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy>=3.0->pytextrank) (0.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\asha m v\anaconda3\lib\site-packages (from jinja2->spacy>=3.0->pytextrank) (2.0.1)

# %%
#import necessary libraries
import spacy
import pytextrank

# %%
nlp = spacy.load("en_core_web_sm")

# %%
# Create spaCy pipeline and add textrank to it
nlp.add_pipe("textrank")

# %%
text = '''Deep learning (also known as deep structured learning) is part of a broader family of machine learning methods based on artificial neural networks with representation learning. Learning can be supervised, semi-supervised or unsupervised. Deep-learning architectures such as deep neural networks, deep belief networks, deep reinforcement learning, recurrent neural networks and convolutional neural networks have been applied to fields including computer vision, speech recognition, natural language processing, machine translation, bioinformatics, drug design, medical image analysis, material inspection and board game programs, where they have produced results comparable to and in some cases surpassing human expert performance. Artificial neural networks (ANNs) were inspired by information processing and distributed communication nodes in biological systems. ANNs have various differences from biological brains. Specifically, neural networks tend to be static and symbolic, while the biological brain of most living organisms is dynamic (plastic) and analogue. The adjective "deep" in deep learning refers to the use of multiple layers in the network. Early work showed that a linear perceptron cannot be a universal classifier, but that a network with a nonpolynomial activation function with one hidden layer of unbounded width can. Deep learning is a modern variation which is concerned with an unbounded number of layers of bounded size, which permits practical application and optimized implementation, while retaining theoretical universality under mild conditions. In deep learning the layers are also permitted to be heterogeneous and to deviate widely from biologically informed connectionist models, for the sake of efficiency, trainability and understandability, whence the structured part.'''

#Run the spacy pipeline with Textrank algorithm
doc = nlp(text)

# %%
#Take the summary as top 2 ranked sentences in the document
for sent in doc._.textrank.summary(limit_sentences = 2):
    print (sent)
# Out:
# Deep-learning architectures such as deep neural networks, deep belief networks, deep reinforcement learning, recurrent neural networks and convolutional neural networks have been applied to fields including computer vision, speech recognition, natural language processing, machine translation, bioinformatics, drug design, medical image analysis, material inspection and board game programs, where they have produced results comparable to and in some cases surpassing human expert performance.
# Deep learning (also known as deep structured learning) is part of a broader family of machine learning methods based on artificial neural networks with representation learning.

# %%
#Examine the top 10 ranked phrases in the document
phrases_and_ranks = [(phrase.chunks[0],phrase.rank) for phrase in doc._.phrases]
phrases_and_ranks[:10]
# Out:
# [(deep neural networks, 0.10450645554326922),
#  (neural networks, 0.10066061073209571),
#  (Artificial neural networks, 0.0994287687209285),
#  (artificial neural networks, 0.0994287687209285),
#  (convolutional neural networks, 0.09736104689347125),
#  (machine learning methods, 0.09719607714483637),
#  (recurrent neural networks, 0.09677412410360203),
#  (deep structured learning, 0.09665365939639706),
#  (human expert performance, 0.09245334616832093),
#  (deep belief networks, 0.09208361607851129)]
